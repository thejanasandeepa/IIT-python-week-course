# %% [markdown]
# # Week 2 - Phython programming

# %% [markdown]
# ## Variables

# %%
X = 10
Y = "Sri Lanka"
Z = 75.00
print(X)
print(Y)
print(Z)
# Out:
# 10
# Sri Lanka
# 75.0

# %%
print(type(X))
# Out:
# <class 'int'>

# %%
print(type(Y))
# Out:
# <class 'str'>

# %%
print(type(Z))
# Out:
# <class 'float'>

# %% [markdown]
# ## Arithmetic Operators

# %%
y = 3 + 4
print(y)
# Out:
# 7

# %%
x = 5 - 2
print(x)
# Out:
# 3

# %%
z = 5 // 2  #### Floor Division
print(z)
# Out:
# 2

# %% [markdown]
# #### Modulus

# %%
t = 5 % 2
print(t)
# Out:
# 1

# %%
a = 5 
b = 2
a = b
print(a)
# Out:
# 2

# %%
a = 5 
b = 2
a+=b
print(a)
# Out:
# 7

# %%
a = 5 
b = 2
a-=b
print(a)
# Out:
# 3

# %%
a = 5 
b = 2
a*=b
print(a)
# Out:
# 10

# %%
a = 5 
b = 2
a/=b
print(a)
# Out:
# 2.5

# %%
a = 5 
b = 2
a//=b
print(a)
# Out:
# 2

# %%
a = 5 
b = 2
a%=b
print(a)
# Out:
# 1

# %% [markdown]
# #### Comparison Operators

# %%
a = 5 
b = 2
a==b
print(a==b)
# Out:
# False

# %%
a = 5 
b = 2
a!=b
print(a!=b)
# Out:
# True

# %% [markdown]
# #### Logical Operators

# %% [markdown]
# ##### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ##### AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ##### OR

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# #### SUM

# %%
num1 = int(input("Enter the number 1 value"))
num2 = int(input("Enter the number 2 value"))
Sum = num1 + num2
print(Sum)
# Out:
# Enter the number 1 value 23
# Enter the number 2 value 34
# 57
