# %%
print("IIT class")
# Out:
# IIT class

# %%
print("IIT class2")
# Out:
# IIT class2

# %% [markdown]
# # This is the statement

# %% [markdown]
# # IIT python class

# %% [markdown]
# ## Week 1 homework

# %% [markdown]
# Very first command - print

# %%
print("Hello Sri Lanka")
# Out:
# Hello Sri Lanka

# %%
print('Hi Sri Lanka')
# Out:
# Hi Sri Lanka

# %%
print("My name is Thejana Dissanayake")
print("I studies as a cybersecurity student")
print("I am currently learning python programming")
# Out:
# My name is Thejana Dissanayake
# I studies as a cybersecurity student
# I am currently learning python programming
